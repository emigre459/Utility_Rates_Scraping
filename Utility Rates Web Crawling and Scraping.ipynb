# %% [markdown]
# # First Things First
#
# To start with, I'm simply going to build a basic web crawler then, using the domains from the URDB source URLs file, I'll randomly sample 1000 to see what their robots.txt file says (to keep it simple, I'll parse them first to see which ones are empty/missing, then check to see what the non-missing/non-empty ones say. For reference, the standards for constructing a robots.txt file [is explained here](http://www.robotstxt.org/robotstxt.html).

# %%
import pandas as pd

# %%
URLs = pd.read_table('URDB_URLs_9-24-18.txt', names = ['Tariff Sheet URL'])
URLs.drop_duplicates(inplace = True)
URLs
# Out:
#                                         Tariff Sheet URL
# 0      http://www.iid.com/Modules/ShowDocument.aspx?d...
# 1      http://villageofarcade.org/departments/public-...
# 2      http://cecelec.coopwebbuilder.com/sites/cecele...
# 3      http://www.wakeforestnc.gov/client_resources/r...
# 4         http://www.rrvcoop.com/content/security-lights
# 5      http://www.prairielandelectric.com/Rates_PDF/M...
# 6         http://www.talquinelectric.com/rates_elec.aspx
# 7      http://www.midstateelectric.coop/customer-serv...
# 8      http://www.surprisevalleyelectric.org/_uploads...
# 9      http://www.mainepublicservice.com/media/40402/...
# 10     http://www.ecirec.coop/admin/upload/editor/fil...
# 11     http://psc.wi.gov/apps40/tariffs/viewfile.aspx...
# 12          http://www.singingriver.com/Files/LGS-15.pdf
# 13     http://www.delaware.coop/sites/default/files/T...
# 14     http://www.iid.com/Modules/ShowDocument.aspx?d...
# 15        http://www.bartlettec.coop/ServiceandFees.aspx
# 16     http://www.clatskaniepud.com/index.php/rate-sc...
# 17     http://www.sanpatricioelectric.org/electricser...
# 18                       http://www.npec.org/slrates.htm
# 19     http://www.neelectric.com/pdf/rate-large-comme...
# 20     http://sfwater.org/modules/showdocument.aspx?d...
# 21        http://www.brmemc.com/Electric_Rate_Sheet.aspx
# 22     http://www.cme.coop/Member_Services/rates/Sche...
# 23     https://www.swepco.com/global/utilities/lib/do...
# 25     http://www.iplpower.com/Our_Company/Rates/Rate...
# 26                                 http://www.iclp.coop/
# 27     http://www.claycountyelectric.com/content/summ...
# 28     http://lodielectric.com/commercial/rateform.as...
# 29     http://www.morristownutilities.org/General_Pow...
# 30     https://www.swepco.com/global/utilities/lib/do...
# ...                                                  ...
# 38433  https://oge.com/wps/wcm/connect/1354757f-c19f-...
# 38434  http://www.oge.com/Documents/ARK/2011%20Arkans...
# 38438  https://oge.com/wps/wcm/connect/de176c54-2711-...
# 38439  http://oge.com/Documents/ARK/2011%20Arkansas%2...
# 38440  http://www.oge.com/Documents/OK/6.40%20GS-TOU.pdf
# 38441  https://oge.com/wps/wcm/connect/ef1b9f4d-6213-...
# 38452  https://www.chelanpud.org/docs/default-source/...
# 38462  https://www.eversource.com/content/docs/defaul...
# 38514        https://www.otpco.com/media/1384/nd_901.pdf
# 38515        https://www.otpco.com/media/1385/nd_902.pdf
# 38516       https://www.otpco.com/media/1387/nd_1001.pdf
# 38519       https://www.otpco.com/media/1388/nd_1002.pdf
# 38521       https://www.otpco.com/media/1389/nd_1003.pdf
# 38524       https://www.otpco.com/media/1392/nd_1005.pdf
# 38528       https://www.otpco.com/media/1353/nd_1102.pdf
# 38530       https://www.otpco.com/media/1356/nd_1105.pdf
# 38541  https://www.blackhillsenergy.com/sites/default...
# 38553    http://www.blackhillspower.com/pdf/SDTariff.pdf
# 38624  https://www.consumersenergy.com/-/media/CE/Doc...
# 38677  http://www.michigan.gov/documents/mpsc/dtee1cu...
# 38794  https://www.aepohio.com/global/utilities/lib/d...
# 38795  https://www2.dps.ny.gov/ETS/jobs/display/downl...
# 38820  https://www.aepohio.com/global/utilities/lib/d...
# 38822  https://nj.pseg.com/-/media/pseg/public-site/d...
# 38836  https://www.firstenergycorp.com/content/dam/cu...
# 38858  https://www.firstenergycorp.com/content/dam/cu...
# 38945  https://www.peco.com/SiteCollectionDocuments/R...
# 38949  https://www.peco.com/SiteCollectionDocuments/C...
# 38994  https://www.nyseg.com/wps/wcm/connect/16c28c6c...
# 39042  https://www.lipower.org/wp-content/uploads/201...
#
# [7969 rows x 1 columns]

# %% [markdown]
# # The Procedure
#
# Based upon some very brief looking-over of these data, it seems like I'll need to do a few things to clean these URLs up first:
#
# 1. Check how many unique values there are relative to the DataFrame size
# 2. Reduce all URLs to their primary domain (e.g. https://www.nyseg.com/)
# 3. Remove all duplicates
# 4. Slap "robots.txt" on the end
# 5. Drop duplicate URLs again, since we probably now have more!
# 5. Run these through scrapy

# %%
#Clean up some messy URLs - na = True because we intend to apply ~ to NOT the resultant series ultimately
is_http = (URLs['Tariff Sheet URL'].str.split("/", expand = True)[0].str.contains("http", na = True))
is_ftp = (URLs['Tariff Sheet URL'].str.split("/", expand = True)[0].str.contains("ftp", na = True))

bad_URLs = (~is_http & ~is_ftp)
bad_URLs.sum()

URLs.loc[bad_URLs,'Tariff Sheet URL'] = "h" + URLs.loc[bad_URLs,'Tariff Sheet URL']
#URLs.loc[36010]

# %%
#Find only the domain portion of the URL + http... and then add /robots.txt to the end

#No good, it doesn't work for FTP sites
URLs['Utility Domain URL'] = URLs['Tariff Sheet URL'].str.extract(pat = r'(https*://[^/]+)')

URLs['robots.txt URL'] = URLs['Utility Domain URL'] + '/robots.txt'

URLs.drop_duplicates(inplace = True)
URLs
# Out:
#                                         Tariff Sheet URL  \
# 0      http://www.iid.com/Modules/ShowDocument.aspx?d...
# 1      http://villageofarcade.org/departments/public-...
# 2      http://cecelec.coopwebbuilder.com/sites/cecele...
# 3      http://www.wakeforestnc.gov/client_resources/r...
# 4         http://www.rrvcoop.com/content/security-lights
# 5      http://www.prairielandelectric.com/Rates_PDF/M...
# 6         http://www.talquinelectric.com/rates_elec.aspx
# 7      http://www.midstateelectric.coop/customer-serv...
# 8      http://www.surprisevalleyelectric.org/_uploads...
# 9      http://www.mainepublicservice.com/media/40402/...
# 10     http://www.ecirec.coop/admin/upload/editor/fil...
# 11     http://psc.wi.gov/apps40/tariffs/viewfile.aspx...
# 12          http://www.singingriver.com/Files/LGS-15.pdf
# 13     http://www.delaware.coop/sites/default/files/T...
# 14     http://www.iid.com/Modules/ShowDocument.aspx?d...
# 15        http://www.bartlettec.coop/ServiceandFees.aspx
# 16     http://www.clatskaniepud.com/index.php/rate-sc...
# 17     http://www.sanpatricioelectric.org/electricser...
# 18                       http://www.npec.org/slrates.htm
# 19     http://www.neelectric.com/pdf/rate-large-comme...
# 20     http://sfwater.org/modules/showdocument.aspx?d...
# 21        http://www.brmemc.com/Electric_Rate_Sheet.aspx
# 22     http://www.cme.coop/Member_Services/rates/Sche...
# 23     https://www.swepco.com/global/utilities/lib/do...
# 25     http://www.iplpower.com/Our_Company/Rates/Rate...
# 26                                 http://www.iclp.coop/
# 27     http://www.claycountyelectric.com/content/summ...
# 28     http://lodielectric.com/commercial/rateform.as...
# 29     http://www.morristownutilities.org/General_Pow...
# 30     https://www.swepco.com/global/utilities/lib/do...
# ...                                                  ...
# 38433  https://oge.com/wps/wcm/connect/1354757f-c19f-...
# 38434  http://www.oge.com/Documents/ARK/2011%20Arkans...
# 38438  https://oge.com/wps/wcm/connect/de176c54-2711-...
# 38439  http://oge.com/Documents/ARK/2011%20Arkansas%2...
# 38440  http://www.oge.com/Documents/OK/6.40%20GS-TOU.pdf
# 38441  https://oge.com/wps/wcm/connect/ef1b9f4d-6213-...
# 38452  https://www.chelanpud.org/docs/default-source/...
# 38462  https://www.eversource.com/content/docs/defaul...
# 38514        https://www.otpco.com/media/1384/nd_901.pdf
# 38515        https://www.otpco.com/media/1385/nd_902.pdf
# 38516       https://www.otpco.com/media/1387/nd_1001.pdf
# 38519       https://www.otpco.com/media/1388/nd_1002.pdf
# 38521       https://www.otpco.com/media/1389/nd_1003.pdf
# 38524       https://www.otpco.com/media/1392/nd_1005.pdf
# 38528       https://www.otpco.com/media/1353/nd_1102.pdf
# 38530       https://www.otpco.com/media/1356/nd_1105.pdf
# 38541  https://www.blackhillsenergy.com/sites/default...
# 38553    http://www.blackhillspower.com/pdf/SDTariff.pdf
# 38624  https://www.consumersenergy.com/-/media/CE/Doc...
# 38677  http://www.michigan.gov/documents/mpsc/dtee1cu...
# 38794  https://www.aepohio.com/global/utilities/lib/d...
# 38795  https://www2.dps.ny.gov/ETS/jobs/display/downl...
# 38820  https://www.aepohio.com/global/utilities/lib/d...
# 38822  https://nj.pseg.com/-/media/pseg/public-site/d...
# 38836  https://www.firstenergycorp.com/content/dam/cu...
# 38858  https://www.firstenergycorp.com/content/dam/cu...
# 38945  https://www.peco.com/SiteCollectionDocuments/R...
# 38949  https://www.peco.com/SiteCollectionDocuments/C...
# 38994  https://www.nyseg.com/wps/wcm/connect/16c28c6c...
# 39042  https://www.lipower.org/wp-content/uploads/201...
#
#                           Utility Domain URL  \
# 0                         http://www.iid.com
# 1                 http://villageofarcade.org
# 2          http://cecelec.coopwebbuilder.com
# 3                http://www.wakeforestnc.gov
# 4                     http://www.rrvcoop.com
# 5         http://www.prairielandelectric.com
# 6             http://www.talquinelectric.com
# 7           http://www.midstateelectric.coop
# 8      http://www.surprisevalleyelectric.org
# 9          http://www.mainepublicservice.com
# 10                    http://www.ecirec.coop
# 11                         http://psc.wi.gov
# 12               http://www.singingriver.com
# 13                  http://www.delaware.coop
# 14                        http://www.iid.com
# 15                http://www.bartlettec.coop
# 16              http://www.clatskaniepud.com
# 17        http://www.sanpatricioelectric.org
# 18                       http://www.npec.org
# 19                 http://www.neelectric.com
# 20                        http://sfwater.org
# 21                     http://www.brmemc.com
# 22                       http://www.cme.coop
# 23                    https://www.swepco.com
# 25                   http://www.iplpower.com
# 26                      http://www.iclp.coop
# 27         http://www.claycountyelectric.com
# 28                   http://lodielectric.com
# 29        http://www.morristownutilities.org
# 30                    https://www.swepco.com
# ...                                      ...
# 38433                        https://oge.com
# 38434                     http://www.oge.com
# 38438                        https://oge.com
# 38439                         http://oge.com
# 38440                     http://www.oge.com
# 38441                        https://oge.com
# 38452              https://www.chelanpud.org
# 38462             https://www.eversource.com
# 38514                  https://www.otpco.com
# 38515                  https://www.otpco.com
# 38516                  https://www.otpco.com
# 38519                  https://www.otpco.com
# 38521                  https://www.otpco.com
# 38524                  https://www.otpco.com
# 38528                  https://www.otpco.com
# 38530                  https://www.otpco.com
# 38541       https://www.blackhillsenergy.com
# 38553         http://www.blackhillspower.com
# 38624        https://www.consumersenergy.com
# 38677                http://www.michigan.gov
# 38794                https://www.aepohio.com
# 38795                https://www2.dps.ny.gov
# 38820                https://www.aepohio.com
# 38822                    https://nj.pseg.com
# 38836        https://www.firstenergycorp.com
# 38858        https://www.firstenergycorp.com
# 38945                   https://www.peco.com
# 38949                   https://www.peco.com
# 38994                  https://www.nyseg.com
# 39042                https://www.lipower.org
#
#                                          robots.txt URL
# 0                         http://www.iid.com/robots.txt
# 1                 http://villageofarcade.org/robots.txt
# 2          http://cecelec.coopwebbuilder.com/robots.txt
# 3                http://www.wakeforestnc.gov/robots.txt
# 4                     http://www.rrvcoop.com/robots.txt
# 5         http://www.prairielandelectric.com/robots.txt
# 6             http://www.talquinelectric.com/robots.txt
# 7           http://www.midstateelectric.coop/robots.txt
# 8      http://www.surprisevalleyelectric.org/robots.txt
# 9          http://www.mainepublicservice.com/robots.txt
# 10                    http://www.ecirec.coop/robots.txt
# 11                         http://psc.wi.gov/robots.txt
# 12               http://www.singingriver.com/robots.txt
# 13                  http://www.delaware.coop/robots.txt
# 14                        http://www.iid.com/robots.txt
# 15                http://www.bartlettec.coop/robots.txt
# 16              http://www.clatskaniepud.com/robots.txt
# 17        http://www.sanpatricioelectric.org/robots.txt
# 18                       http://www.npec.org/robots.txt
# 19                 http://www.neelectric.com/robots.txt
# 20                        http://sfwater.org/robots.txt
# 21                     http://www.brmemc.com/robots.txt
# 22                       http://www.cme.coop/robots.txt
# 23                    https://www.swepco.com/robots.txt
# 25                   http://www.iplpower.com/robots.txt
# 26                      http://www.iclp.coop/robots.txt
# 27         http://www.claycountyelectric.com/robots.txt
# 28                   http://lodielectric.com/robots.txt
# 29        http://www.morristownutilities.org/robots.txt
# 30                    https://www.swepco.com/robots.txt
# ...                                                 ...
# 38433                        https://oge.com/robots.txt
# 38434                     http://www.oge.com/robots.txt
# 38438                        https://oge.com/robots.txt
# 38439                         http://oge.com/robots.txt
# 38440                     http://www.oge.com/robots.txt
# 38441                        https://oge.com/robots.txt
# 38452              https://www.chelanpud.org/robots.txt
# 38462             https://www.eversource.com/robots.txt
# 38514                  https://www.otpco.com/robots.txt
# 38515                  https://www.otpco.com/robots.txt
# 38516                  https://www.otpco.com/robots.txt
# 38519                  https://www.otpco.com/robots.txt
# 38521                  https://www.otpco.com/robots.txt
# 38524                  https://www.otpco.com/robots.txt
# 38528                  https://www.otpco.com/robots.txt
# 38530                  https://www.otpco.com/robots.txt
# 38541       https://www.blackhillsenergy.com/robots.txt
# 38553         http://www.blackhillspower.com/robots.txt
# 38624        https://www.consumersenergy.com/robots.txt
# 38677                http://www.michigan.gov/robots.txt
# 38794                https://www.aepohio.com/robots.txt
# 38795                https://www2.dps.ny.gov/robots.txt
# 38820                https://www.aepohio.com/robots.txt
# 38822                    https://nj.pseg.com/robots.txt
# 38836        https://www.firstenergycorp.com/robots.txt
# 38858        https://www.firstenergycorp.com/robots.txt
# 38945                   https://www.peco.com/robots.txt
# 38949                   https://www.peco.com/robots.txt
# 38994                  https://www.nyseg.com/robots.txt
# 39042                https://www.lipower.org/robots.txt
#
# [7920 rows x 3 columns]

# %%
URLs.isnull().sum()
# Out:
# Tariff Sheet URL      0
# Utility Domain URL    2
# robots.txt URL        2
# dtype: int64

# %%
URLs[URLs['Utility Domain URL'].isnull()]
# Out:
#                                        Tariff Sheet URL Utility Domain URL  \
# 3198  ftp://data.amec.org/Rural%20Missouri%20Backpag...                NaN
# 4893  ftp://www.city.ketchikan.ak.us/pub/municode/11...                NaN
#
#      robots.txt URL
# 3198            NaN
# 4893            NaN

# %%
#URLs['Tariff Sheet URL'].str.split(pat = r'^https*://.+/', expand = True)
#This doesn't do what I want right now, but gets the filenames, so maybe useful down the road?

# %%
URLs['Utility Domain URL'].nunique()
# Out:
# 1979

# %%
URLs['Crawling_Allowed'] = False

# %%
URLs['Num_Ratepayers'] = 0

# %%
URLs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7920 entries, 0 to 39042
# Data columns (total 5 columns):
# Tariff Sheet URL      7920 non-null object
# Utility Domain URL    7918 non-null object
# robots.txt URL        7918 non-null object
# Crawling_Allowed      7920 non-null bool
# Num_Ratepayers        7920 non-null int64
# dtypes: bool(1), int64(1), object(3)
# memory usage: 317.1+ KB

# %%
list(URLs['Utility Domain URL'].unique())
# Out:
# ['http://www.iid.com',
#  'http://villageofarcade.org',
#  'http://cecelec.coopwebbuilder.com',
#  'http://www.wakeforestnc.gov',
#  'http://www.rrvcoop.com',
#  'http://www.prairielandelectric.com',
#  'http://www.talquinelectric.com',
#  'http://www.midstateelectric.coop',
#  'http://www.surprisevalleyelectric.org',
#  'http://www.mainepublicservice.com',
#  'http://www.ecirec.coop',
#  'http://psc.wi.gov',
#  'http://www.singingriver.com',
#  'http://www.delaware.coop',
#  'http://www.bartlettec.coop',
#  'http://www.clatskaniepud.com',
#  'http://www.sanpatricioelectric.org',
#  'http://www.npec.org',
#  'http://www.neelectric.com',
#  'http://sfwater.org',
#  'http://www.brmemc.com',
#  'http://www.cme.coop',
#  'https://www.swepco.com',
#  'http://www.iplpower.com',
#  'http://www.iclp.coop',
#  'http://www.claycountyelectric.com',
#  'http://lodielectric.com',
#  'http://www.morristownutilities.org',
#  'http://www.adrian.govoffice2.com',
#  'http://milford.ia.us',
#  'http://www.ci.statesville.nc.us',
#  'http://www.avistautilities.com',
#  'http://www.nli.coop',
#  'http://www.ssemc.com',
#  'http://jocarroll.coopwebbuilder2.com',
#  'http://bancroftiowa.com',
#  'http://westcentralelectric.coop',
#  'http://jcremc.com',
#  'http://www.sepb.net',
#  'http://www.volgacity.com',
#  'http://www.sce.com',
#  'http://www.pacificpower.net',
#  'http://www.entergy-texas.com',
#  'http://edmondok.com',
#  'http://www.nfecoop.com',
#  'http://www.spec.coop',
#  'http://www.lacreek.com',
#  'http://www.columbusco-op.org',
#  'http://www.ci.longmont.co.us',
#  'http://www.vernonelectric.org',
#  'http://www.pud-ri.org',
#  'http://www.pbutilities.com',
#  'http://www.osagecity.com',
#  'http://www.trico.coop',
#  'http://www.holden-ma.gov',
#  'http://www.cheyennelight.com',
#  'http://www.mwenergy.com',
#  'http://www.hawkeyerec.com',
#  'http://aemc.coop',
#  'http://www.dmea.com',
#  'http://www.clarkpublicutilities.com',
#  'http://publicutilities.columbus.gov',
#  'http://www.losalamosnm.us',
#  'http://www.cityofhoward.com',
#  'http://www.moreno-valley.ca.us',
#  'http://www.lcpd1.com',
#  'http://www.cityoflexington.com',
#  'https://billing.pve.coop',
#  'http://www.alputilities.com',
#  'http://www.pickwick-electric.com',
#  'http://www.cityofplattsburgh-ny.gov',
#  'http://www.swec-coop.org',
#  'https://www.lbwl.com',
#  'http://www.breckenridgemn.net',
#  'http://www.salemelectric.com',
#  'http://rrelectric.coopwebbuilder2.com',
#  'http://www.nppd.com',
#  'http://www.fcpud.com',
#  'http://www.town.wallingford.ct.us',
#  'http://www.seattle.gov',
#  'http://www.eastpointcity.org',
#  'http://www.gulfpower.com',
#  'http://www.belw.org',
#  'http://www.chelanpud.org',
#  'http://www.sgcity.org',
#  'http://www.meckelec.org',
#  'http://www.cityofpaloalto.org',
#  'http://www.ci.madison.mn.us',
#  'http://www.cityofvernon.org',
#  'http://npec.org',
#  'http://des.dmcsdev.com',
#  'http://gcea.coopwebbuilder2.com',
#  'http://www.riversideca.gov',
#  'http://cityofpa.us',
#  'http://mgemc.coopwebbuilder2.com',
#  'https://www.indianamichiganpower.com',
#  'http://www.sbunet.com',
#  'http://www.duke-energy.com',
#  'http://library.municode.com',
#  'http://www.butlerppd.com',
#  'http://www.cityofmarshall.com',
#  'http://www.linncountyrec.com',
#  'http://www.ayden.com',
#  'http://www.keysenergy.com',
#  'http://www.gladstonemi.org',
#  'https://library.municode.com',
#  'http://www.midamericanenergy.com',
#  'http://www.mcrea.org',
#  'http://www.sullivanil.us',
#  'http://www.arlingtonmn.com',
#  'http://www.frederickok.org',
#  'http://www.sussexrec.com',
#  'http://kauai.coopwebbuilder.com',
#  'http://facts.psc.state.ga.us',
#  'http://www.beld.com',
#  'http://www.wascoelectric.com',
#  'http://www.ci.azusa.ca.us',
#  'http://www.cmec.coop',
#  'http://www.mub-albertville.com',
#  'http://www.amlegal.com',
#  'http://www.bcremc.com',
#  'http://www.custerpower.com',
#  'http://www.mcpbpu.com',
#  'http://www.tcemc.org',
#  'http://www.ppec.coop',
#  'http://www.fpunet.com',
#  'http://www.sciremc.com',
#  'http://www.erppd.com',
#  'http://www.easleyutilities.com',
#  'http://mncable.net',
#  'http://www.mitchellcity.net',
#  'https://cas.sharepoint.illinoisstate.edu',
#  'http://www.sweci.com',
#  'http://www.cwremc.com',
#  'http://www.cityofmadisonsd.com',
#  'http://missoulaelectric.com',
#  'http://media.wix.com',
#  'http://www.dce.coop',
#  'http://www.aztecnm.gov',
#  'http://www.vtes.vt.edu',
#  'http://www.hfrecc.com',
#  'http://www.perennialpower.com',
#  'http://ucnsb.org',
#  'http://z2.franklinlegal.net',
#  'https://www.nvenergy.com',
#  'http://energy.gov',
#  'http://www.newhamptonia.com',
#  'http://www.aswater.com',
#  'https://www.connexusenergy.com',
#  'http://www.riogrande.coop',
#  'http://nwec.coopwebbuilder.com',
#  'http://www.pkmcoop.com',
#  'http://www.guc.com',
#  'http://www.fcgov.com',
#  'http://new.washingtoncity.org',
#  'http://www.orbgdpu.com',
#  'http://cityofgreendale.net',
#  'http://www.lebanonmissouri.org',
#  'http://www.naelectric.com',
#  'http://www.flatheadelectric.com',
#  'http://www.oakdalerec.com',
#  'http://www.nypa.gov',
#  'http://www.natchitochesla.gov',
#  'https://www.xcelenergy.com',
#  'https://www.psoklahoma.com',
#  'http://www.farmersrecc.com',
#  'http://psc.ky.gov',
#  'http://www.alta-tec.net',
#  'http://www.clintonutilities.com',
#  'http://www.jasperremc.com',
#  'http://www.plummerid.govoffice3.com',
#  'http://www.pge.com',
#  'http://www.cityofchewelah.org',
#  'https://www.appalachianpower.com',
#  'http://www.uppco.com',
#  'http://www.osceolaelectric.com',
#  'http://www.ci.mora.mn.us',
#  'http://www.skrecc.com',
#  'http://www.lub.org',
#  'https://www.csu.org',
#  'http://www.greenmountainpower.com',
#  'http://www.screc.com',
#  'http://www.ccelectric.org',
#  'http://fpb.cc',
#  'http://www.kec-sd.coop',
#  'http://www.jacksonohio.us',
#  'http://www.mifflinburgborough.org',
#  'http://www.sie.coop',
#  'http://www.ssvec.org',
#  'http://www.lagrangeremc.com',
#  'http://www.mlandp.com',
#  'http://www.selma.govoffice2.com',
#  'http://www.townofblackstoneva.com',
#  'http://www.cityofiola.com',
#  'http://www.gardnerkansas.gov',
#  'http://www.nespower.com',
#  'https://harris.lagrange-ga.org',
#  'http://www.dawsonpower.com',
#  'http://www.waltonemc.com',
#  'http://www.cityofgeneseo.com',
#  'http://missionvalleypower.org',
#  'http://www.freeportelectric.com',
#  'http://www.ci.waseca.mn.us',
#  'http://www.meadvillemo.com',
#  'http://www.dleg.state.mi.us',
#  'http://www.cimarronks.org',
#  'http://www.georgetownma.gov',
#  'http://psc.state.wy.us',
#  'https://www.santeecooper.com',
#  'http://www.villageofwinnetka.org',
#  'http://www.vermillion.us',
#  'http://cnmec.org',
#  'http://www.ozarkelectric.com',
#  'http://ure.com',
#  'http://www.northfield-vt.gov',
#  'http://www.hudsonlight.com',
#  'http://tcec.coopwebbuilder.com',
#  'http://www.pvrea.com',
#  'http://www.frenchbroademc.com',
#  'http://www.northwesternenergy.com',
#  'http://nlrelectric.com',
#  'http://www.clarksvillede.com',
#  'http://www.ctec.coop',
#  'http://www.maconelectric.com',
#  'http://www.holycross.com',
#  'http://www.nicholasville.org',
#  'http://www.lpea.com',
#  'http://www.concordma.gov',
#  'http://www.cityofwatervilleks.org',
#  'http://www.cvea.org',
#  'http://www.kcpl.com',
#  'http://medinaec.org',
#  'http://www.clearwaterpower.com',
#  'http://www.aptalaska.com',
#  'http://www.craigheadelectric.coop',
#  'http://www.vermontelectric.coop',
#  'http://www.danville-va.gov',
#  'http://www.cityofsheboyganfalls.com',
#  'http://chickasaw.coop',
#  'http://www.hope-wl.com',
#  'http://www.cbec.cc',
#  'http://www.greenwoodcpw.com',
#  'http://marshallremc.coopwebbuilder.com',
#  'http://www.pella-cea.org',
#  'http://fcec.coop',
#  'http://www.owenelectric.com',
#  'http://www.itasca-mantrap.com',
#  'http://rooseveltppd.com',
#  'http://www.xcelenergy.com',
#  'http://www.cmpco.com',
#  'http://www.aikenco-op.org',
#  'http://www.bpw.zeeland.mi.us',
#  'http://www.vinelandcity.org',
#  'http://valleycity.govoffice.com',
#  'http://www.gibsonemc.com',
#  'http://www.bensonmn.org',
#  'http://www.wolfeboronh.us',
#  'http://www.swppd.com',
#  'http://www.danvers.govoffice.com',
#  'http://www.heartlandpower.com',
#  'http://www.wyan.org',
#  'http://erppd.com',
#  'http://www.kodiakelectric.com',
#  'http://www.cecnet.net',
#  'http://www.empiredistrict.com',
#  'http://www.entergy-louisiana.com',
#  'http://okcoop.coopwebbuilder2.com',
#  'http://www.pemc.coop',
#  'http://www.cityofalexandriala.com',
#  'http://www.sceg.com',
#  'https://www.kcpl.com',
#  'http://www.bpu.com',
#  'http://www.claverack.com',
#  'http://www.emec.com',
#  'http://www.alamedamp.com',
#  'http://www.mauielectric.com',
#  'http://bluestemelectric.com',
#  'http://www.nipsco.com',
#  'http://www.vil.spencerport.ny.us',
#  'http://www.kvremc.com',
#  'http://www.granitefallsnc.com',
#  'http://billing.georgetown.org',
#  'http://www.unitedelectric.coop',
#  'http://www.lpandl.com',
#  'http://www.westriver.com',
#  'http://www.psrec.coop',
#  'http://www.preco.org',
#  'http://www.nixa.com',
#  'http://www.brookingsutilities.com',
#  'http://www.rivierautilities.com',
#  'http://www.duboisrec.com',
#  'http://www.pikevillenc.com',
#  'http://www.baycitymi.org',
#  'http://www.srec.org',
#  'http://www.cityofec.com',
#  'http://www.nnppd.com',
#  'http://unitil.com',
#  'http://schuylerdevelopment.net',
#  'http://www.cecpower.coop',
#  'http://www.cityofmangum.com',
#  'http://www.fremontne.gov',
#  'http://www.entergy-mississippi.com',
#  'http://hotec.coop',
#  'http://osage.net',
#  'http://www.pcremc.com',
#  'http://www.monroenc.org',
#  'http://www.cityofwauchula.com',
#  'https://www.rockymountainpower.net',
#  'http://kcelectric.coop',
#  'http://www.westarenergy.com',
#  'http://www.les.com',
#  'http://www.maryvillegov.com',
#  'http://www.cityofluverne.org',
#  'http://www.grda.com',
#  'http://www.vea.coop',
#  'http://www.gallupnm.gov',
#  'http://www.adamn.gov',
#  'http://www.btes.net',
#  'http://www.belmont-ma.gov',
#  'http://www.bolivarelectric.com',
#  'http://www.cmu.com',
#  'http://www.warrenminnesota.com',
#  'http://clintonsc.govoffice3.com',
#  'http://www.south-haven.com',
#  'http://www.mesaaz.gov',
#  'http://www.cameron-mo.com',
#  'http://www.wcremc.com',
#  'http://mohawkmunicipalcommission.org',
#  'http://nnec.coopwebbuilder.com',
#  'http://nuwnotes1.nu.com',
#  'http://www.ci.niles.mi.us',
#  'http://www.wbmlp.org',
#  'http://www.princeton-il.com',
#  'http://www.kinstonpublicservices.com',
#  'http://www.jewettcitydpu.com',
#  'http://www.webstercity.com',
#  'http://menard.coopwebbuilder.com',
#  'http://www.niobrara-electric.org',
#  'http://www.washingtonin.us',
#  'http://www.aub.org',
#  'http://www.jemezcoop.org',
#  'http://www.bpu.org',
#  'http://www.ci.albemarle.nc.us',
#  'http://www.psc.state.wv.us',
#  'http://www.hmlp.com',
#  'http://www.alpenapower.com',
#  'http://www.washingtonelectric.coop',
#  'https://www.hamilton-city.org',
#  'http://www.tid.org',
#  'http://www.ouc.com',
#  'http://www.lakecountrypower.coop',
#  'http://www.mpei.com',
#  'http://www.naecoop.com',
#  'http://vec.org',
#  'http://www.wahkiakumpud.org',
#  'http://www.cityofmelrose.com',
#  'http://www.weci.net',
#  'http://www.poncacityok.gov',
#  'http://lakeparkmn.com',
#  'http://www.oasis.oati.com',
#  'http://www.ieca.coop',
#  'http://www.steubenrec.com',
#  'http://www.wellsvilleny.com',
#  'http://www.smithfield-nc.com',
#  'http://www.bedfordrec.com',
#  'http://ks-osagecity2.civicplus.com',
#  'http://www.nueceselectric.org',
#  'http://www.hwe.coop',
#  'http://www.hwecoop.com',
#  'http://www.laurinburg.org',
#  'http://www.vec.coop',
#  'http://www.cityofharborsprings.com',
#  'http://www.glacierelectric.com',
#  'http://www.hawaiianelectric.com',
#  'http://houstoncountyelec.com',
#  'http://www.menard.com',
#  'http://www.stfranciskansas.com',
#  'http://www.lamarlightandpower.com',
#  'http://www.cityofbellevillekansas.com',
#  'http://clpower.com',
#  'http://www.ci.kinston.nc.us',
#  'http://www.aspenpitkin.com',
#  'http://southcentralelectric.coopwebbuilder.com',
#  'https://www.stearnselectric.org',
#  'http://www.osagevalley.com',
#  'http://nrlp.appstate.edu',
#  'http://www.westoregon.org',
#  'http://www.ueci.coop',
#  'http://www.egovlink.com',
#  'http://www.polkburnett.coopwebbuilder.com',
#  'http://precorp.coop',
#  'http://www.ncelec.org',
#  'https://www.okanoganpud.org',
#  'http://www.consolidatedelectric.coop',
#  'http://www.mseb.net',
#  'http://dahlberglightandpower.com',
#  'http://www.bgohio.org',
#  'http://www.gmu-ia.com',
#  'http://weci.coopwebbuilder.com',
#  'http://www.halifaxemc.com',
#  'http://www.meramecregion.org',
#  'http://trinidad.co.gov',
#  'https://www.firstenergycorp.com',
#  'http://www.okcoop.org',
#  'http://www.cityofcentralia.com',
#  'http://www.peruutilities.com',
#  'http://www.rp-l.com',
#  'http://www.enerstar.com',
#  'http://www.mceci.com',
#  'http://www.bcnv.org',
#  'http://www.blueridgeemc.com',
#  'http://www.chaskamn.com',
#  'http://www.i-m-u.com',
#  'http://www.carbonpower.com',
#  'http://www.staples.govoffice.com',
#  'http://www.loup.com',
#  'http://www.shrewsbury-ma.gov',
#  'http://www.okanoganelectriccoop.com',
#  'http://www.intermountain-rea.com',
#  'http://www.mnvalleyrec.com',
#  'http://www.petoskey.us',
#  'http://www.cityofmilford.com',
#  'http://www.lexingtonnc.net',
#  'http://www.tampaelectric.com',
#  'http://www.cemc.com',
#  'http://aecoop.org',
#  'http://www.beci.org',
#  'https://siliconvalleypower.com',
#  'http://www.templetonlight.com',
#  'http://www.mansfieldelectric.com',
#  'http://www.ci.buffalo.mn.us',
#  'http://www.lockhartpower.com',
#  'http://www.we-energies.com',
#  'http://faith.govoffice.com',
#  'http://www.dmremc.com',
#  'http://www.bueci.org',
#  'http://www.lakelandelectric.com',
#  'http://www.pioneerelectric.coop',
#  'http://www.mountainelectric.com',
#  'http://www.pgec.coop',
#  'http://www.pcepa.com',
#  'http://www.townofbargersville.org',
#  'http://lge-ku.com',
#  'http://www.hilco.coop',
#  'http://www.culpeperva.gov',
#  'http://www.portlandgeneral.com',
#  'http://www.miamiokla.net',
#  'http://www.lincolnelectric.coop',
#  'http://united-cs.com',
#  'http://www.fillmorecity.org',
#  'http://www.algomautilities.com',
#  'http://www.rollamunicipalutilities.org',
#  'http://www.gridley.ca.us',
#  'http://www.mcec.org',
#  'http://www.cityofnewberry.com',
#  'http://www.tclp.org',
#  'http://www.stclairsville.com',
#  'http://www.nmprc.state.nm.us',
#  'http://www.entergy-neworleans.com',
#  'http://www.mvea.com',
#  'http://fultonmo.org',
#  'http://www.bangorhydro.com',
#  'http://www.cityofsouthport.com',
#  'http://hrec.coop',
#  'http://townofscotlandneck.com',
#  'http://www.agralite.coop',
#  'http://z2codes.franklinlegal.net',
#  'http://www.cvecoop.com',
#  'http://www.traverseelectric.com',
#  'http://www.torcnm.org',
#  'http://www.rockymountainpower.net',
#  'http://www.newknoxville.com',
#  'http://ashland.or.us',
#  'http://www.mercedid.org',
#  'http://www.snopud.com',
#  'http://www.cpsenergy.com',
#  'http://www.wiregrass.coop',
#  'http://www.hillsdalebpu.com',
#  'http://www.hawley.govoffice.com',
#  'http://dazmcj35iv4sa.cloudfront.net',
#  'http://www.worthingtonpublicutilities.com',
#  'http://farmington-mo.gov',
#  'http://www.wcec.org',
#  'http://www.salemmo.com',
#  'http://cityofeldridgeia.org',
#  'http://www.pacificpud.org',
#  'http://www.schuylkillhaven.org',
#  'http://www.sargentne.com',
#  'http://www.mcecoop.com',
#  'http://lanescott.coopwebbuilder2.com',
#  'http://www.swrea.com',
#  'http://www.kutztownboro.org',
#  'http://www.kua.com',
#  'http://www.columbiacity.net',
#  'http://www.cpws.com',
#  'http://www.sallisawok.org',
#  'https://www.comed.com',
#  'http://cityofhugoton.com',
#  'http://washingtonelec.wpengine.com',
#  'http://www.kaysvillecity.com',
#  'http://www.hutchinsonutilities.com',
#  'http://www.bedfordva.gov',
#  'http://ww3.oppd.com',
#  'http://central.coopwebbuilder2.com',
#  'http://www.cityofholdrege.org',
#  'http://www.anzaelectric.org',
#  'http://www.avec.org',
#  'http://www.wheatbelt.com',
#  'http://wste.coop',
#  'http://www.spepa.com',
#  'http://www.cityofwatonga.org',
#  'http://www.cityofgriffin.com',
#  'http://www.gvea.com',
#  'http://tpwa.cityoftahlequah.com',
#  'http://www.carrollecc.com',
#  'http://www.celp.com',
#  'http://www.townofrussell.us',
#  'http://www.cenhud.com',
#  'https://www.pacificpower.net',
#  'https://www.duquesnelight.com',
#  'http://www.socorroelectric.com',
#  'http://www.lakota-nd.com',
#  'http://www.tvec.net',
#  'http://www.kve.coop',
#  'http://www.aelp.com',
#  'http://www.eea.coop',
#  'http://www.bigsandyrecc.com',
#  'http://www.lvenergy.com',
#  'http://www.sesdofutah.com',
#  'http://www.akenergyefficiency.org',
#  'http://www.siouxvalleyenergy.com',
#  'http://www.logansportutilities.com',
#  'http://www.montana-dakota.com',
#  'http://www.lmud.org',
#  'http://sec.coopwebbuilder.com',
#  'https://www.otpco.com',
#  'http://www.mid.org',
#  'http://www.sedgwickcountyelectric.coop',
#  'https://www.westerville.org',
#  'http://www.chappellne.org',
#  'http://www.ci.colton.ca.us',
#  'http://www.ci.new-prague.mn.us',
#  'http://www.colorado.gov',
#  'http://www.shawano.tv',
#  'https://www.lcec.net',
#  'https://www.sce.com',
#  'http://www.hop-electric.com',
#  'http://ci.bluffton.in.us',
#  'https://www.aepohio.com',
#  'http://www.chambersburgpa.gov',
#  'http://westplains.net',
#  'http://www.discovercorona.com',
#  'https://www.burlingtonelectric.com',
#  'http://www.entergy-arkansas.com',
#  'http://www.dteenergy.com',
#  'http://www.mcremc.coop',
#  'http://www.ahec.coop',
#  'http://www.recinfocenter.com',
#  'http://culive.ruralitedevelopment.net',
#  'http://ci.longmont.co.us',
#  'http://www.dcremc.com',
#  'https://www.uesaz.com',
#  'http://www.wrangell.com',
#  'https://www.dakotaelectric.com',
#  'http://www.ravallielectric.com',
#  'https://www.ameren.com',
#  'http://www.cityofblaine.com',
#  'http://www.apscservices.info',
#  'http://www.eesonline.org',
#  'http://www.fairmont.org',
#  'http://www.google.com',
#  'https://www.ladwp.com',
#  'https://oge.com',
#  'http://www.nremc.com',
#  'http://www.semoelectric.coop',
#  'http://stoughtonutilities.com',
#  'http://rca.alaska.gov',
#  'http://www.newportutilities.com',
#  'http://www.middletownin.com',
#  'http://www.rpu.org',
#  'http://mfcity.com',
#  'http://a-m-u.net',
#  'http://www.mged.com',
#  'http://www.cecmo.com',
#  'http://cullmanpowerboard.com',
#  'http://www.harlannet.com',
#  'http://pawhuska.org',
#  'http://www.sweetwaterutilities.com',
#  'http://www.bagleymn.us',
#  'http://clarksvillede.com',
#  'http://www.ci.ellensburg.wa.us',
#  'http://grantpud.org',
#  'https://www.fpl.com',
#  'http://provopower.org',
#  'http://www.nationalgridus.com',
#  'http://www.myrec.coop',
#  'https://www2.dps.ny.gov',
#  'https://www9.nationalgridus.com',
#  'http://austinenergy.com',
#  'http://regarchive.sdge.com',
#  'http://www.mtemc.com',
#  'http://www.cumberlandvalley.coop',
#  'http://www.cityoflivingston-tx.com',
#  'http://en.openei.org',
#  'http://albanyutil.org',
#  'http://mohaveelectric.coopwebbuilder.com',
#  'https://www.nypa.gov',
#  'http://www.eweb.org',
#  'https://www.umatillaelectric.com',
#  'http://www.white-river-electric-association.org',
#  'http://www.coldwater.org',
#  'http://www.caneyforkec.com',
#  'http://www.fallscitynebraska.org',
#  'http://www.jocarroll.com',
#  'http://www.intercountyenergy.net',
#  'http://www.escanaba.org',
#  'http://www.homeworks.org',
#  'http://www.bhcec.com',
#  'http://www.ci.lake-crystal.mn.us',
#  'http://www.villageofgreenisland.com',
#  'http://www.ace-power.com',
#  'http://www.sturgismi.gov',
#  'https://www.faypwc.com',
#  'http://www.timesuniononline.com',
#  'http://www.clevelandutilities.com',
#  'http://www.epelectric.com',
#  'http://www.town.richlands.va.us',
#  'http://www.geneseo-il.us',
#  'http://www.kemelectric.com',
#  'http://www.cityofclaycenter.com',
#  'http://documents.ecec.com',
#  'http://www.cfu.net',
#  'http://hardwickvt.org',
#  'http://www.bighornrea.com',
#  'http://www.coffeyville.com',
#  'http://www.lowell-light.org',
#  'http://www.tpcg.org',
#  'http://www.dmumn.com',
#  'http://winterset.govoffice.com',
#  'http://www.newnanutilities.org',
#  'http://www.minneapolisksorg.org',
#  'http://www.canbyutility.org',
#  'http://www.kremc.com',
#  'http://www.mwlvt.com',
#  'http://www.cityofdenton.com',
#  'http://cityweb.lakesnet.net',
#  'http://www.elkriverutilities.com',
#  'http://www.ci.shasta-lake.ca.us',
#  'http://www.remcsteuben.com',
#  'http://www.lockhart-tx.org',
#  'https://www.ghpud.org',
#  'http://www.ci.brownfield.tx.us',
#  'http://lumbeeriver.coopwebbuilder2.com',
#  'http://www.delta-co.gov',
#  'http://www.wgeld.org',
#  'http://butler.coopwebbuilder.com',
#  'http://www.shelbyenergy.com',
#  'http://www.cityofpa.us',
#  'http://www.pieg.com',
#  'http://www.highwestenergy.com',
#  'http://www.saukcentre.govoffice2.com',
#  'http://www.ci.gillette.wy.us',
#  'http://www.e-u.cc',
#  'http://www.redlakeelectric.com',
#  'http://www.vvec.com',
#  'http://www.holstonelectric.com',
#  'http://www.mnpower.com',
#  'http://www.cuivreriverelectriccooperative.com.asp1-2.dfw1-1.websitetestlink.com',
#  'http://wrec.coop',
#  'http://www.churchville.net',
#  'http://www.martinsville-va.gov',
#  'http://www.buckeyerec.com',
#  'http://discovercoronadwp.com',
#  'http://www.hollandbpw.com',
#  'http://www.jwemc.org',
#  'http://www.townofsteilacoom.com',
#  'http://www.cityofbartow.net',
#  'http://www.grotonelectric.org',
#  'http://www.cityofjacksonga.com',
#  'http://www.burbankwaterandpower.com',
#  'http://www.mleainc.com',
#  'http://www.magicvalley.coop',
#  'http://www.ngemc.com',
#  'http://www.ci.new-bern.nc.us',
#  'http://www.siloamsprings.com',
#  'http://ritablancaelectric.com',
#  'http://www.mayfieldews.com',
#  'http://villageofpennyan.com',
#  'http://bereautilities.com',
#  'http://www.townofclaytonnc.org',
#  'http://www.sylacauga.net',
#  'http://www.owatonnautilities.com',
#  'http://192.163.229.126',
#  'http://www.cookeville-tn.org',
#  'http://www.cityofgonzales.org',
#  'http://www.fpuc.com',
#  'http://www.highpointnc.gov',
#  'http://www.lincolnks.org',
#  'http://www.naeci.com',
#  'http://www.subutil.com',
#  'http://www.brundidge.org',
#  'http://www.heyburnidaho.org',
#  'http://www.puc.texas.gov',
#  'http://www.harrisonrea.com',
#  'http://firelandsec.coopwebbuilder.com',
#  'http://www.newtonnc.gov',
#  'http://auburnbpw.com',
#  'http://avamissouri.org',
#  'http://www.cityutilities.net',
#  'http://www.ameren.com',
#  'http://www.geus.org',
#  'http://www.ed3online.org',
#  'http://www.butlerborough.com',
#  'http://www.crete-ne.com',
#  'http://baldwincity.citycode.net',
#  'http://www.epud.org',
#  'http://www.oakridgetn.gov',
#  'http://www.alabamapower.com',
#  'http://www.cemc.org',
#  'http://riverlandenergy.coopwebbuilder.com',
#  'https://www.vectren.com',
#  'http://www.acecwi.com',
#  'http://www.femelectric.coop',
#  'http://www.enfieldnc.org',
#  'https://www.dixiepower.com',
#  'http://www.midwestecc.com',
#  'http://www.haywoodemc.com',
#  'http://burbankca.gov',
#  'http://www.tricountyelectric.org',
#  'http://www.maidennc.com',
#  'http://www.cityofcharlevoix.org',
#  'http://www.nodakelectric.com',
#  'http://www.sleca.com',
#  'http://www.callawayelectric.com',
#  'http://city.grand-island.com',
#  'http://www.ci.richland.wa.us',
#  'http://hermannmo.com',
#  'http://www.dallasnc.net',
#  'http://www.cityofsewardne.com',
#  'http://www.consumersenergy.com',
#  'http://www.versaillesohio.cc',
#  'http://www.cityofowensville.com',
#  'http://www.smpa.com',
#  'http://www.harrisonremc.com',
#  'http://www.rosenet.org',
#  'http://www.alliantenergy.com',
#  'http://ci.pierre.sd.us',
#  'https://billing.fme.coop',
#  'http://www.cityofalcoa-tn.gov',
#  'http://www.jacksonmo.org',
#  'http://www.ocalafl.org',
#  'http://jacksonremc.coopwebbuilder2.com',
#  'http://paullinaiowa.com',
#  'http://www.bge.com',
#  'http://www.kpub.com',
#  'https://www.alliantenergy.com',
#  'http://www.fremontnc.gov',
#  'http://www.wcecnet.net',
#  'http://www.guernsey.govoffice2.com',
#  'http://www.cowlitzpud.org',
#  'http://city-chelsea.org',
#  'https://www.cleco.com',
#  'http://omu.org',
#  'http://www.bluebonnetelectric.coop',
#  'http://www.demco.org',
#  'http://glencoelightandpower.com',
#  'http://www.oecc.com',
#  'http://www.crppd.com',
#  'http://www.smeco.coop',
#  'http://www.pseg.com',
#  'http://www.cityofforestcity.com',
#  'http://www.wadena.org',
#  'http://www.parkelectric.coop',
#  'https://www.jea.com',
#  'http://www.roanokeelectric.com',
#  'http://www.swlp.com',
#  'http://www.ceca.coop',
#  'http://www.garkaneenergy.com',
#  'http://www.elmhurstmutual.org',
#  'http://www.rse.coop',
#  'http://www.opalco.com',
#  'http://www.highwest-energy.com',
#  'http://hubbard.cboss-staged.com',
#  'http://www.chelco.com',
#  'http://www.collegeparkga.com',
#  'http://www.clearwater-polk.com',
#  'http://www.coned.com',
#  'http://www.cityofbayard.net',
#  'http://www.bardstowncable.net',
#  'http://fairfax.govoffice.com',
#  'http://www.cityofalliance.net',
#  'http://www.unioncounty.coop',
#  'http://www.sterlingcodifiers.com',
#  'http://www.rrelectric.com',
#  'http://dawsonpower.com',
#  'http://www.chugachelectric.com',
#  'http://cc.state.az.us',
#  'http://www.prosperitysc.com',
#  'http://www.madisonvillegov.com',
#  'https://www.duke-energy.com',
#  'http://www.rmld.com',
#  'http://www.hmpl.com',
#  'http://www.mwpowerarchive.com',
#  'http://www.tcec.com',
#  'http://www.prema.coop',
#  'http://www.lrec.coop',
#  'http://www.co-mo.coop',
#  'http://www.otsegoec.coop',
#  'https://www.firstelectric.coop',
#  'http://www.sunriverelectric.coop',
#  'http://www.ci.loveland.co.us',
#  'http://www.wrec.coop',
#  'http://www.nobleremc.com',
#  'http://060d74e241f3763edec3-fa618b14bd32534cc7f0bb25828e9921.r85.cf5.rackcdn.com',
#  'http://www.forcvec.com',
#  'http://www.banderaelectric.com',
#  'http://www.mcleanelectric.com',
#  'http://www.precc.com',
#  'http://www.centralelectriconline.com',
#  'http://www.franklinpud.com',
#  'http://www.mpw.org',
#  'http://www.townoflouisburg.com',
#  'http://www.bradytx.us',
#  'http://www.kub.org',
#  'http://pitcairnborough.us',
#  'http://www.bdec.coop',
#  'http://iclp.coopwebbuilder2.com',
#  'http://www.glasgow-ky.com',
#  'http://www.pemdunk.com',
#  'http://www.greercpw.com',
#  'http://www.commercega.org',
#  'http://www.olivia.mn.us',
#  'http://www.mc-power.com',
#  'http://llec.coop',
#  'http://www.dremc.com',
#  'http://rollinghills.coopwebbuilder.com',
#  'http://www.ghblp.org',
#  'http://www.cityofsitka.com',
#  'http://www.mlgw.com',
#  'http://www.gvp.org',
#  'http://www.wintervillenc.com',
#  'http://heyburnidaho.org',
#  'http://pec.coop',
#  'http://www.union-power.com',
#  'https://www.nationalgridus.com',
#  'http://ok-pawhuska.civiccities.com',
#  'http://www.mytpu.org',
#  'http://www.grotonutilities.com',
#  'http://www.burlingameks.com',
#  'http://www.cullmanpowerboard.com',
#  'http://www.heartland-rec.com',
#  'http://www.kiwash.coop',
#  'http://www.fpl.com',
#  'http://cityofkingman.com',
#  'http://westerncoop.coopwebbuilder.com',
#  'http://bigcountry.coopwebbuilder2.com',
#  'http://www.maldenmo.com',
#  'http://www.plateauelectric.com',
#  'http://cwecoop.coopwebbuilder.com',
#  'http://www.lus.org',
#  'http://www.klickitatpud.com',
#  'http://secure.provocitypower.com',
#  'http://www.norwaymi.com',
#  'http://www.cityofseattle.net',
#  'http://www.mcrecc.com',
#  'http://www.bhec.com',
#  'http://www.ci.wickenburg.az.us',
#  'http://stemc.coopwebbuilder2.com',
#  'http://yvea.coopwebbuilder2.com',
#  'http://www.midsouthsynergy.com',
#  'http://www.salemva.gov',
#  'http://www.littletonwaterandlight.org',
#  'http://www.shelbyvillepower.com',
#  'http://www.ocontoelectric.com',
#  'http://www.oru.com',
#  'http://www.robertsdale.org',
#  'http://consolidatedelectric.coop',
#  'http://www.hpuc.com',
#  'http://www.eastonutilities.com',
#  'http://www.bvea.coop',
#  'http://www.siouxfalls.org',
#  'http://www.wwvremc.com',
#  'http://ecode360.com',
#  'http://www.georgiapower.com',
#  'http://www.pepco.com',
#  'http://www.ephrataboro.org',
#  'http://www.carteretcravenelectric.coop',
#  'http://www.village.rantoul.il.us',
#  'https://www.idahopower.com',
#  'http://www.southernpd.com',
#  'http://www.selco.shrewsburyma.gov',
#  'http://www.smyrna.delaware.gov',
#  'http://www.e-co-op.com',
#  'http://www.centraliamo.org',
#  'http://www.townofstantonsburg.com',
#  'http://www.highlandsnc.org',
#  'http://www.city-of-torrington.org',
#  'http://discoverosborne.com',
#  'http://www.beartoothelectric.com',
#  'http://www.oppd.com',
#  'http://www.ntua.com',
#  'http://www.siea.com',
#  'https://www.clayelectric.com',
#  'https://www.secoenergy.com',
#  'http://www.arkvalley.com',
#  'http://www.cbec.coop',
#  'http://www.tub.net',
#  'http://www.ncppd.com',
#  'http://www.peoplesrec.com',
#  'http://www.bountifulutah.gov',
#  'http://www.cityofkm.com',
#  'http://www.cwlp.com',
#  'https://www.psrec.coop',
#  'http://www.wtownky.org',
#  'http://pse.com',
#  'http://www.nbutexas.com',
#  'http://www.rmu.net',
#  'http://www.sacosage.com',
#  'http://www.cityofaltus.org',
#  'http://www.crec.coop',
#  'http://www.dsoelectric.com',
#  'http://www.ci.independence.mo.us',
#  'http://www.ashland.or.us',
#  'http://www.town.hull.ma.us',
#  'http://www.svec-coop.com',
#  'http://www.merrimac01860.info',
#  'http://urecc.coop',
#  'http://www.grayson-collin.coop',
#  'http://www.tannerelectric.coop',
#  'http://www.cityofnegaunee.com',
#  'http://www.cityofbushnellfl.com',
#  'http://www.covingtones.com',
#  'http://www.kaukaunautilities.com',
#  'http://www.cwpower.com',
#  'http://www.nwasco.com',
#  'https://sites.google.com',
#  'http://www.crmu.net',
#  'http://s3.amazonaws.com',
#  'http://villageofarcanum.com',
#  'http://wlp.waverlyia.com',
#  'http://www.riverlandenergy.com',
#  'http://www.ugi.com',
#  'http://www.austinutilities.com',
#  'http://cityofholdrege.org',
#  'http://www.mpsutility.com',
#  'http://kitcarson.coopwebbuilder.com',
#  'https://www.wkrecc.com',
#  'http://www.ttd.gov',
#  'http://www.gilbertmn.org',
#  'http://www.cityofwayne.org',
#  'https://docs.google.com',
#  'http://www.cityofperryok.com',
#  'http://www.washingtonks.net',
#  'http://www.btutilities.com',
#  'http://www.ecode360.com',
#  'http://www.russepb.com',
#  'https://www.tep.com',
#  'http://www.bemc.org',
#  'http://www.tec.coop',
#  'http://www.ci.gothenburg.ne.us',
#  'http://www.stclair-gov.org',
#  'http://www.hartselleutilities.org',
#  'http://mindennebraska.org',
#  'http://www.laurelne.com',
#  'http://www.lewiscountyrec.org',
#  'https://www.cl-p.com',
#  'https://hmlp.com',
#  'http://www.idahopower.com',
#  'https://www.epb.net',
#  'http://kiamichielectric.coopwebbuilder.com',
#  'http://www.cityofmonett.com',
#  'http://www.fkec.com',
#  'http://ttd.gov',
#  'http://www.cwecoop.com',
#  'http://www.mesystem.net',
#  'http://villageoflanse.org',
#  'http://www.cityofdysartia.com',
#  'http://www.wildriceelectric.com',
#  'http://www.norcrossga.net',
#  'http://www.cityofsafford.us',
#  'http://www.svec.coop',
#  'http://cobbemc.coopwebbuilder2.com',
#  'http://www.farmersrec.com',
#  'http://pesenergize.com',
#  'http://www.homerelectric.com',
#  'http://www.cityofmccleary.com',
#  'http://www.smunet.net',
#  'http://www.nhec.com',
#  'http://www.cityofunion.net',
#  'http://www.cityofloveland.org',
#  'http://www.wemc.com',
#  'http://www.conwaygreene.com',
#  'http://ci.harrisonville.mo.us',
#  'http://navopache.coopwebbuilder.com',
#  'http://www.flec.org',
#  'http://www.fvutil.com',
#  'http://www.maquoketaia.com',
#  'http://dvec.coopwebbuilder.com',
#  'https://www.beatrice.ne.gov',
#  'http://www.cascade-locks.or.us',
#  ...]

# %%
#Export as CSV file for pulling into scrapy spider
#Only need the domain URLs for robots checking, but push out all of them anyhow
URLs.to_csv("Rate_URLs.csv")

# %%
URLs[]

# %% [markdown]
# # TO DO
# 1. Figure out how to record robots.txt text via `scrapy`
# 2. Figure out rules for what we care about in robots.txt file
#     1. Check if file exists, if not set `Crawling_Allowed = True`
#     2. Check if file is blank. If so, set `Crawling_Allowed = True`
#     2. If file doesn't have a line `User-agent: *`, then set `Crawling_Allowed = True`. This is fine because our bot doesn't exist yet and thus couldn't be disallowed or allowed by name in the first place.
#     3. If the code below is in robots.txt and nothing else, set `Crawling_Allowed = True`
#         `User-agent: *`
#         `Disallow: `
#     4. Check for the code below in file. If it exists, move on.
#         `User-agent: *`
#         `Disallow: /`
#     5. For those remaining with `User-agent: *`:
#         1. Compare our tariff sheet URL one-level-up parent directories to what is disallowed and set `Crawling_Allowed = True` if our directory isn't disallowed explicitly
# 3. For those with `Crawling_Allowed = True`, use their `Num_Ratepayers` value their score and final metric of "% Allowed" will be `(URLs['Num_Ratepayers'] * URLs['Crawling_Allowed']).sum()/URLs['Num_Ratepayers'].sum()`
