# %% [markdown]
# # First Things First
#
# To start with, I'm simply going to build a basic web crawler then, using the domains from the URDB source URLs file, I'll randomly sample 1000 to see what their robots.txt file says (to keep it simple, I'll parse them first to see which ones are empty/missing, then check to see what the non-missing/non-empty ones say. For reference, the standards for constructing a robots.txt file [is explained here](http://www.robotstxt.org/robotstxt.html).

# %%
import pandas as pd

# %%
URLs = pd.read_table('URDB_URLs_9-24-18.txt', names = ['Tariff Sheet URL'])
URLs.drop_duplicates(inplace = True)
URLs
# Out:
#                                         Tariff Sheet URL
# 0      http://www.iid.com/Modules/ShowDocument.aspx?d...
# 1      http://villageofarcade.org/departments/public-...
# 2      http://cecelec.coopwebbuilder.com/sites/cecele...
# 3      http://www.wakeforestnc.gov/client_resources/r...
# 4         http://www.rrvcoop.com/content/security-lights
# 5      http://www.prairielandelectric.com/Rates_PDF/M...
# 6         http://www.talquinelectric.com/rates_elec.aspx
# 7      http://www.midstateelectric.coop/customer-serv...
# 8      http://www.surprisevalleyelectric.org/_uploads...
# 9      http://www.mainepublicservice.com/media/40402/...
# 10     http://www.ecirec.coop/admin/upload/editor/fil...
# 11     http://psc.wi.gov/apps40/tariffs/viewfile.aspx...
# 12          http://www.singingriver.com/Files/LGS-15.pdf
# 13     http://www.delaware.coop/sites/default/files/T...
# 14     http://www.iid.com/Modules/ShowDocument.aspx?d...
# 15        http://www.bartlettec.coop/ServiceandFees.aspx
# 16     http://www.clatskaniepud.com/index.php/rate-sc...
# 17     http://www.sanpatricioelectric.org/electricser...
# 18                       http://www.npec.org/slrates.htm
# 19     http://www.neelectric.com/pdf/rate-large-comme...
# 20     http://sfwater.org/modules/showdocument.aspx?d...
# 21        http://www.brmemc.com/Electric_Rate_Sheet.aspx
# 22     http://www.cme.coop/Member_Services/rates/Sche...
# 23     https://www.swepco.com/global/utilities/lib/do...
# 25     http://www.iplpower.com/Our_Company/Rates/Rate...
# 26                                 http://www.iclp.coop/
# 27     http://www.claycountyelectric.com/content/summ...
# 28     http://lodielectric.com/commercial/rateform.as...
# 29     http://www.morristownutilities.org/General_Pow...
# 30     https://www.swepco.com/global/utilities/lib/do...
# ...                                                  ...
# 38433  https://oge.com/wps/wcm/connect/1354757f-c19f-...
# 38434  http://www.oge.com/Documents/ARK/2011%20Arkans...
# 38438  https://oge.com/wps/wcm/connect/de176c54-2711-...
# 38439  http://oge.com/Documents/ARK/2011%20Arkansas%2...
# 38440  http://www.oge.com/Documents/OK/6.40%20GS-TOU.pdf
# 38441  https://oge.com/wps/wcm/connect/ef1b9f4d-6213-...
# 38452  https://www.chelanpud.org/docs/default-source/...
# 38462  https://www.eversource.com/content/docs/defaul...
# 38514        https://www.otpco.com/media/1384/nd_901.pdf
# 38515        https://www.otpco.com/media/1385/nd_902.pdf
# 38516       https://www.otpco.com/media/1387/nd_1001.pdf
# 38519       https://www.otpco.com/media/1388/nd_1002.pdf
# 38521       https://www.otpco.com/media/1389/nd_1003.pdf
# 38524       https://www.otpco.com/media/1392/nd_1005.pdf
# 38528       https://www.otpco.com/media/1353/nd_1102.pdf
# 38530       https://www.otpco.com/media/1356/nd_1105.pdf
# 38541  https://www.blackhillsenergy.com/sites/default...
# 38553    http://www.blackhillspower.com/pdf/SDTariff.pdf
# 38624  https://www.consumersenergy.com/-/media/CE/Doc...
# 38677  http://www.michigan.gov/documents/mpsc/dtee1cu...
# 38794  https://www.aepohio.com/global/utilities/lib/d...
# 38795  https://www2.dps.ny.gov/ETS/jobs/display/downl...
# 38820  https://www.aepohio.com/global/utilities/lib/d...
# 38822  https://nj.pseg.com/-/media/pseg/public-site/d...
# 38836  https://www.firstenergycorp.com/content/dam/cu...
# 38858  https://www.firstenergycorp.com/content/dam/cu...
# 38945  https://www.peco.com/SiteCollectionDocuments/R...
# 38949  https://www.peco.com/SiteCollectionDocuments/C...
# 38994  https://www.nyseg.com/wps/wcm/connect/16c28c6c...
# 39042  https://www.lipower.org/wp-content/uploads/201...
#
# [7969 rows x 1 columns]

# %% [markdown]
# # The Procedure
#
# Based upon some very brief looking-over of these data, it seems like I'll need to do a few things to clean these URLs up first:
#
# 1. Check how many unique values there are relative to the DataFrame size
# 2. Reduce all URLs to their primary domain (e.g. https://www.nyseg.com/)
# 3. Remove all duplicates
# 4. Slap "robots.txt" on the end
# 5. Drop duplicate URLs again, since we probably now have more!
# 5. Run these through scrapy

# %%
#Clean up some messy URLs - na = True because we intend to apply ~ to NOT the resultant series ultimately
is_http = (URLs['Tariff Sheet URL'].str.split("/", expand = True)[0].str.contains("http", na = True))
is_ftp = (URLs['Tariff Sheet URL'].str.split("/", expand = True)[0].str.contains("ftp", na = True))

bad_URLs = (~is_http & ~is_ftp)
bad_URLs.sum()

URLs.loc[bad_URLs,'Tariff Sheet URL'] = "h" + URLs.loc[bad_URLs,'Tariff Sheet URL']
#URLs.loc[36010]

# %%
#Find only the domain portion of the URL + http... and then add /robots.txt to the end

#No good, it doesn't work for FTP sites
URLs['Utility Domain URL'] = URLs['Tariff Sheet URL'].str.extract(pat = r'(https*://[^/]+)')

URLs['robots.txt URL'] = URLs['Utility Domain URL'] + '/robots.txt'

URLs.drop_duplicates(inplace = True)
URLs
# Out:
#                                         Tariff Sheet URL  \
# 0      http://www.iid.com/Modules/ShowDocument.aspx?d...
# 1      http://villageofarcade.org/departments/public-...
# 2      http://cecelec.coopwebbuilder.com/sites/cecele...
# 3      http://www.wakeforestnc.gov/client_resources/r...
# 4         http://www.rrvcoop.com/content/security-lights
# 5      http://www.prairielandelectric.com/Rates_PDF/M...
# 6         http://www.talquinelectric.com/rates_elec.aspx
# 7      http://www.midstateelectric.coop/customer-serv...
# 8      http://www.surprisevalleyelectric.org/_uploads...
# 9      http://www.mainepublicservice.com/media/40402/...
# 10     http://www.ecirec.coop/admin/upload/editor/fil...
# 11     http://psc.wi.gov/apps40/tariffs/viewfile.aspx...
# 12          http://www.singingriver.com/Files/LGS-15.pdf
# 13     http://www.delaware.coop/sites/default/files/T...
# 14     http://www.iid.com/Modules/ShowDocument.aspx?d...
# 15        http://www.bartlettec.coop/ServiceandFees.aspx
# 16     http://www.clatskaniepud.com/index.php/rate-sc...
# 17     http://www.sanpatricioelectric.org/electricser...
# 18                       http://www.npec.org/slrates.htm
# 19     http://www.neelectric.com/pdf/rate-large-comme...
# 20     http://sfwater.org/modules/showdocument.aspx?d...
# 21        http://www.brmemc.com/Electric_Rate_Sheet.aspx
# 22     http://www.cme.coop/Member_Services/rates/Sche...
# 23     https://www.swepco.com/global/utilities/lib/do...
# 25     http://www.iplpower.com/Our_Company/Rates/Rate...
# 26                                 http://www.iclp.coop/
# 27     http://www.claycountyelectric.com/content/summ...
# 28     http://lodielectric.com/commercial/rateform.as...
# 29     http://www.morristownutilities.org/General_Pow...
# 30     https://www.swepco.com/global/utilities/lib/do...
# ...                                                  ...
# 38433  https://oge.com/wps/wcm/connect/1354757f-c19f-...
# 38434  http://www.oge.com/Documents/ARK/2011%20Arkans...
# 38438  https://oge.com/wps/wcm/connect/de176c54-2711-...
# 38439  http://oge.com/Documents/ARK/2011%20Arkansas%2...
# 38440  http://www.oge.com/Documents/OK/6.40%20GS-TOU.pdf
# 38441  https://oge.com/wps/wcm/connect/ef1b9f4d-6213-...
# 38452  https://www.chelanpud.org/docs/default-source/...
# 38462  https://www.eversource.com/content/docs/defaul...
# 38514        https://www.otpco.com/media/1384/nd_901.pdf
# 38515        https://www.otpco.com/media/1385/nd_902.pdf
# 38516       https://www.otpco.com/media/1387/nd_1001.pdf
# 38519       https://www.otpco.com/media/1388/nd_1002.pdf
# 38521       https://www.otpco.com/media/1389/nd_1003.pdf
# 38524       https://www.otpco.com/media/1392/nd_1005.pdf
# 38528       https://www.otpco.com/media/1353/nd_1102.pdf
# 38530       https://www.otpco.com/media/1356/nd_1105.pdf
# 38541  https://www.blackhillsenergy.com/sites/default...
# 38553    http://www.blackhillspower.com/pdf/SDTariff.pdf
# 38624  https://www.consumersenergy.com/-/media/CE/Doc...
# 38677  http://www.michigan.gov/documents/mpsc/dtee1cu...
# 38794  https://www.aepohio.com/global/utilities/lib/d...
# 38795  https://www2.dps.ny.gov/ETS/jobs/display/downl...
# 38820  https://www.aepohio.com/global/utilities/lib/d...
# 38822  https://nj.pseg.com/-/media/pseg/public-site/d...
# 38836  https://www.firstenergycorp.com/content/dam/cu...
# 38858  https://www.firstenergycorp.com/content/dam/cu...
# 38945  https://www.peco.com/SiteCollectionDocuments/R...
# 38949  https://www.peco.com/SiteCollectionDocuments/C...
# 38994  https://www.nyseg.com/wps/wcm/connect/16c28c6c...
# 39042  https://www.lipower.org/wp-content/uploads/201...
#
#                           Utility Domain URL  \
# 0                         http://www.iid.com
# 1                 http://villageofarcade.org
# 2          http://cecelec.coopwebbuilder.com
# 3                http://www.wakeforestnc.gov
# 4                     http://www.rrvcoop.com
# 5         http://www.prairielandelectric.com
# 6             http://www.talquinelectric.com
# 7           http://www.midstateelectric.coop
# 8      http://www.surprisevalleyelectric.org
# 9          http://www.mainepublicservice.com
# 10                    http://www.ecirec.coop
# 11                         http://psc.wi.gov
# 12               http://www.singingriver.com
# 13                  http://www.delaware.coop
# 14                        http://www.iid.com
# 15                http://www.bartlettec.coop
# 16              http://www.clatskaniepud.com
# 17        http://www.sanpatricioelectric.org
# 18                       http://www.npec.org
# 19                 http://www.neelectric.com
# 20                        http://sfwater.org
# 21                     http://www.brmemc.com
# 22                       http://www.cme.coop
# 23                    https://www.swepco.com
# 25                   http://www.iplpower.com
# 26                      http://www.iclp.coop
# 27         http://www.claycountyelectric.com
# 28                   http://lodielectric.com
# 29        http://www.morristownutilities.org
# 30                    https://www.swepco.com
# ...                                      ...
# 38433                        https://oge.com
# 38434                     http://www.oge.com
# 38438                        https://oge.com
# 38439                         http://oge.com
# 38440                     http://www.oge.com
# 38441                        https://oge.com
# 38452              https://www.chelanpud.org
# 38462             https://www.eversource.com
# 38514                  https://www.otpco.com
# 38515                  https://www.otpco.com
# 38516                  https://www.otpco.com
# 38519                  https://www.otpco.com
# 38521                  https://www.otpco.com
# 38524                  https://www.otpco.com
# 38528                  https://www.otpco.com
# 38530                  https://www.otpco.com
# 38541       https://www.blackhillsenergy.com
# 38553         http://www.blackhillspower.com
# 38624        https://www.consumersenergy.com
# 38677                http://www.michigan.gov
# 38794                https://www.aepohio.com
# 38795                https://www2.dps.ny.gov
# 38820                https://www.aepohio.com
# 38822                    https://nj.pseg.com
# 38836        https://www.firstenergycorp.com
# 38858        https://www.firstenergycorp.com
# 38945                   https://www.peco.com
# 38949                   https://www.peco.com
# 38994                  https://www.nyseg.com
# 39042                https://www.lipower.org
#
#                                          robots.txt URL
# 0                         http://www.iid.com/robots.txt
# 1                 http://villageofarcade.org/robots.txt
# 2          http://cecelec.coopwebbuilder.com/robots.txt
# 3                http://www.wakeforestnc.gov/robots.txt
# 4                     http://www.rrvcoop.com/robots.txt
# 5         http://www.prairielandelectric.com/robots.txt
# 6             http://www.talquinelectric.com/robots.txt
# 7           http://www.midstateelectric.coop/robots.txt
# 8      http://www.surprisevalleyelectric.org/robots.txt
# 9          http://www.mainepublicservice.com/robots.txt
# 10                    http://www.ecirec.coop/robots.txt
# 11                         http://psc.wi.gov/robots.txt
# 12               http://www.singingriver.com/robots.txt
# 13                  http://www.delaware.coop/robots.txt
# 14                        http://www.iid.com/robots.txt
# 15                http://www.bartlettec.coop/robots.txt
# 16              http://www.clatskaniepud.com/robots.txt
# 17        http://www.sanpatricioelectric.org/robots.txt
# 18                       http://www.npec.org/robots.txt
# 19                 http://www.neelectric.com/robots.txt
# 20                        http://sfwater.org/robots.txt
# 21                     http://www.brmemc.com/robots.txt
# 22                       http://www.cme.coop/robots.txt
# 23                    https://www.swepco.com/robots.txt
# 25                   http://www.iplpower.com/robots.txt
# 26                      http://www.iclp.coop/robots.txt
# 27         http://www.claycountyelectric.com/robots.txt
# 28                   http://lodielectric.com/robots.txt
# 29        http://www.morristownutilities.org/robots.txt
# 30                    https://www.swepco.com/robots.txt
# ...                                                 ...
# 38433                        https://oge.com/robots.txt
# 38434                     http://www.oge.com/robots.txt
# 38438                        https://oge.com/robots.txt
# 38439                         http://oge.com/robots.txt
# 38440                     http://www.oge.com/robots.txt
# 38441                        https://oge.com/robots.txt
# 38452              https://www.chelanpud.org/robots.txt
# 38462             https://www.eversource.com/robots.txt
# 38514                  https://www.otpco.com/robots.txt
# 38515                  https://www.otpco.com/robots.txt
# 38516                  https://www.otpco.com/robots.txt
# 38519                  https://www.otpco.com/robots.txt
# 38521                  https://www.otpco.com/robots.txt
# 38524                  https://www.otpco.com/robots.txt
# 38528                  https://www.otpco.com/robots.txt
# 38530                  https://www.otpco.com/robots.txt
# 38541       https://www.blackhillsenergy.com/robots.txt
# 38553         http://www.blackhillspower.com/robots.txt
# 38624        https://www.consumersenergy.com/robots.txt
# 38677                http://www.michigan.gov/robots.txt
# 38794                https://www.aepohio.com/robots.txt
# 38795                https://www2.dps.ny.gov/robots.txt
# 38820                https://www.aepohio.com/robots.txt
# 38822                    https://nj.pseg.com/robots.txt
# 38836        https://www.firstenergycorp.com/robots.txt
# 38858        https://www.firstenergycorp.com/robots.txt
# 38945                   https://www.peco.com/robots.txt
# 38949                   https://www.peco.com/robots.txt
# 38994                  https://www.nyseg.com/robots.txt
# 39042                https://www.lipower.org/robots.txt
#
# [7920 rows x 3 columns]

# %%
#All split results are 3-element lists of str, with [2] being the bit we care about
#Since I can't do Series.str.split("/", expand = True) for some odd reason, this will have to do
URLs['Utility Domain (WWW Only)'] = URLs['Utility Domain URL'].str.split("/").str.get(-1)
URLs['Utility Domain (WWW Only)'].drop_duplicates()
# Out:
# 0                                 www.iid.com
# 1                         villageofarcade.org
# 2                  cecelec.coopwebbuilder.com
# 3                        www.wakeforestnc.gov
# 4                             www.rrvcoop.com
# 5                 www.prairielandelectric.com
# 6                     www.talquinelectric.com
# 7                   www.midstateelectric.coop
# 8              www.surprisevalleyelectric.org
# 9                  www.mainepublicservice.com
# 10                            www.ecirec.coop
# 11                                 psc.wi.gov
# 12                       www.singingriver.com
# 13                          www.delaware.coop
# 15                        www.bartlettec.coop
# 16                      www.clatskaniepud.com
# 17                www.sanpatricioelectric.org
# 18                               www.npec.org
# 19                         www.neelectric.com
# 20                                sfwater.org
# 21                             www.brmemc.com
# 22                               www.cme.coop
# 23                             www.swepco.com
# 25                           www.iplpower.com
# 26                              www.iclp.coop
# 27                 www.claycountyelectric.com
# 28                           lodielectric.com
# 29                www.morristownutilities.org
# 31                  www.adrian.govoffice2.com
# 32                              milford.ia.us
#                          ...
# 32705                          www.psc.ky.gov
# 32790         farmersrecc.coopwebbuilder2.com
# 32907                           www.oncor.com
# 33011                      www.satillaemc.com
# 33450                   www.wathenakansas.com
# 33475              infrastructure.sfwater.org
# 34299                               adamn.gov
# 34302                      www.cityofbuhl.com
# 34306                    www.granitefalls.com
# 34314            www.janesville.govoffice.com
# 34316                       cityofhenning.com
# 34321                           www2.erie.gov
# 34328                    www.lanesboro-mn.gov
# 34340           www.villageoflittlevalley.org
# 34354                           sherburne.org
# 34357                      www.sherrillny.org
# 36164                        www.myavista.com
# 36220                cdec.coopwebbuilder2.com
# 36224                              srpnet.com
# 36254              www.siliconvalleypower.com
# 36618                     docs.idahopower.com
# 36783                  www.dominionenergy.com
# 37401                             cobbemc.com
# 37761          jwemc2.cms.coopwebbuilder2.com
# 37773           d2veoet8kyyfpj.cloudfront.net
# 37808                               issuu.com
# 37917                            coastepa.com
# 38213                   www.southernpine.coop
# 38277    northeasternremc.coopwebbuilder2.com
# 38822                             nj.pseg.com
# Name: Utility Domain (WWW Only), Length: 1863, dtype: object

# %%
URLs.isnull().sum()
# Out:
# Tariff Sheet URL             0
# Utility Domain URL           2
# robots.txt URL               2
# Utility Domain (WWW Only)    2
# dtype: int64

# %%
#URLs['Tariff Sheet URL'].str.split(pat = r'^https*://.+/', expand = True)
#This doesn't do what I want right now, but gets the filenames, so maybe useful down the road?

# %%
URLs['Utility Domain URL'].nunique()
# Out:
# 1979

# %%
URLs['Crawling_Allowed'] = False

# %%
URLs['Num_Ratepayers'] = 0

# %%
URLs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7920 entries, 0 to 39042
# Data columns (total 6 columns):
# Tariff Sheet URL             7920 non-null object
# Utility Domain URL           7918 non-null object
# robots.txt URL               7918 non-null object
# Utility Domain (WWW Only)    7918 non-null object
# Crawling_Allowed             7920 non-null bool
# Num_Ratepayers               7920 non-null int64
# dtypes: bool(1), int64(1), object(4)
# memory usage: 379.0+ KB

# %%
#Export as CSV file for pulling into scrapy spider
#Only need the domain URLs for robots checking, but push out all of them anyhow
URLs.to_csv("Rate_URLs.csv")

# %%
#Need to parse log for robots data that allowed crawling
lines = []

with open('URDB/logs/utility_10-23-18.log','r') as f:
    for line in f:
        #Count the good crawls
        if "DEBUG: Crawled" in line:
            lines.append(line)
            
print(lines[:5])
# Out:
# ['2018-10-23 22:23:38 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://www.iid.com/robots.txt> (referer: None)\n', '2018-10-23 22:23:38 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://www.prairielandelectric.com/robots.txt> (referer: None)\n', '2018-10-23 22:23:38 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://www.midstateelectric.coop/robots.txt> (referer: None)\n', '2018-10-23 22:23:38 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://villageofarcade.org/robots.txt> (referer: None)\n', '2018-10-23 22:23:38 [scrapy.core.engine] DEBUG: Crawled (404) <GET http://www.mainepublicservice.com/robots.txt> (referer: None)\n']

# %%
crawled = pd.Series(lines)
crawled = crawled.str.split('DEBUG: Crawled', expand = True)[1]

#Only gives domains for extracts that have robots.txt in the log line, as other lines report on the actual crawl
    #MAY be conservative in that there may not be a successful crawl log line for domain missing robots.txt
crawled = crawled.str.extract(r'<GET https*://(.*)/robots.txt>').dropna()

crawled = crawled[0]
crawled
# Out:
# 0                         www.iid.com
# 1         www.prairielandelectric.com
# 2           www.midstateelectric.coop
# 3                 villageofarcade.org
# 4          www.mainepublicservice.com
# 5      www.surprisevalleyelectric.org
# 6             www.talquinelectric.com
# 8                     www.rrvcoop.com
# 9                www.wakeforestnc.gov
# 13                   singingriver.com
# 15                    www.ecirec.coop
# 16                www.bartlettec.coop
# 18                   singingriver.com
# 21                         psc.wi.gov
# 22              www.clatskaniepud.com
# 23                  www.delaware.coop
# 24                 www.neelectric.com
# 30        www.sanpatricioelectric.org
# 31                     www.brmemc.com
# 32                       www.cme.coop
# 37                   www.iplpower.com
# 38                      www.iclp.coop
# 39         www.claycountyelectric.com
# 42        www.morristownutilities.org
# 43          www.adrian.govoffice2.com
# 44                     www.swepco.com
# 45                       www.npec.org
# 50                       www.nli.coop
# 51                        sfwater.org
# 52                      www.ssemc.com
#                     ...
# 704                   www.naecoop.com
# 706                           vec.org
# 709              www.wahkiakumpud.org
# 710             www.cityofmelrose.com
# 711                      www.weci.net
# 713               www.poncacityok.gov
# 715                    lakeparkmn.com
# 717                www.oasis.oati.com
# 720                     www.ieca.coop
# 721                www.steubenrec.com
# 723              www.wellsvilleny.com
# 727                www.bedfordrec.com
# 729       ks-osagecity2.civicplus.com
# 731            www.nueceselectric.org
# 733                      www.hwe.coop
# 735                   www.hwecoop.com
# 738                www.laurinburg.org
# 739                      www.vec.coop
# 742       www.cityofharborsprings.com
# 743           www.glacierelectric.com
# 746          www.hawaiianelectric.com
# 747             houstoncountyelec.com
# 749                    www.menard.com
# 752               stfranciskansas.com
# 753        www.lamarlightandpower.com
# 755               stfranciskansas.com
# 756    www.cityofbellevillekansas.com
# 759                       clpower.com
# 760              www.ci.kinston.nc.us
# 763               www.cityofaspen.com
# Name: 0, Length: 399, dtype: object

# %%
#Fuzzy match to existing WWW-only domains
from TextSimilarity import best_option

best_option("vec.org", crawled, cluster = True, 
            scorer = None, score_threshold = 90)
# Out:
# ('vec.org', 'www.ssvec.org', 90)

# %% [markdown]
# **It looks like simple fuzz.ratio() scorer is best for this task.**

# %%
results = pd.DataFrame(data = None)

(results['Original Value'], results['Recommended Value'], 
 results['Score']) = zip(*crawled.apply(best_option, args = (crawled, True, None, 90)))
results = results.drop_duplicates().dropna().sort_values('Score', ascending = True)
results
# Out:
#                   Original Value            Recommended Value  Score
# 370                      vec.org                www.ssvec.org     90
# 198                www.ssvec.org                      vec.org     90
# 232        www.maconelectric.com        www.wascoelectric.com     90
# 332                     vea.coop                 www.vea.coop     90
# 88      gcea.coopwebbuilder2.com    mgemc.coopwebbuilder2.com     90
# 92     mgemc.coopwebbuilder2.com     gcea.coopwebbuilder2.com     90
# 117        www.wascoelectric.com        www.maconelectric.com     90
# 157                  www.guc.com                  www.ouc.com     91
# 366                  www.ouc.com                  www.guc.com     91
# 355                  www.aub.org                  www.lub.org     91
# 184                  www.lub.org                  www.aub.org     91
# 136                 www.dce.coop                 www.cme.coop     92
# 230                www.ctec.coop                www.cmec.coop     92
# 386                 www.vec.coop                 www.vea.coop     92
# 72          www.alputilities.com          www.pbutilities.com     92
# 52           www.pbutilities.com         www.alputilities.com     92
# 46                 www.spec.coop                www.ppec.coop     92
# 326                 www.vea.coop                 www.vec.coop     92
# 341               www.wcremc.com               www.bcremc.com     93
# 369              www.naecoop.com              www.nfecoop.com     93
# 316               www.pcremc.com               www.bcremc.com     93
# 188                www.screc.com              www.sciremc.com     93
# 18                www.brmemc.com               www.bcremc.com     93
# 41               www.nfecoop.com              www.naecoop.com     93
# 118               www.bcremc.com               www.brmemc.com     93
# 125              www.sciremc.com                www.screc.com     93
# 133               www.cwremc.com               www.bcremc.com     93
# 16            www.neelectric.com           www.naelectric.com     94
# 162           www.naelectric.com           www.neelectric.com     94
# 238       cityofwatervilleks.org   www.cityofwatervilleks.org     95
# 248  billing.cecpowerup.com/oscp       billing.cecpowerup.com     95
# 249       billing.cecpowerup.com  billing.cecpowerup.com/oscp     95
# 294                www.preco.org                    preco.org     95
# 310      schuylerdevelopment.net  www.schuylerdevelopment.net     95
# 313  www.schuylerdevelopment.net      schuylerdevelopment.net     95
# 90                     fcpud.com                www.fcpud.com     95
# 80                 www.fcpud.com                    fcpud.com     95
# 296                    preco.org                www.preco.org     95
# 155                    ppec.coop                www.ppec.coop     95
# 146                www.ucnsb.org                    ucnsb.org     95
# 219               cimarronks.org           www.cimarronks.org     95
# 170                   psc.ky.gov               psc.ky.gov:443     95
# 174               psc.ky.gov:443                   psc.ky.gov     95
# 141                    ucnsb.org                www.ucnsb.org     95
# 186   www.greenmountainpower.com       greenmountainpower.com     95
# 190       greenmountainpower.com   www.greenmountainpower.com     95
# 134                www.ppec.coop                    ppec.coop     95
# 202       mifflinburgborough.org   www.mifflinburgborough.org     95
# 210          www.ci.waseca.mn.us              ci.waseca.mn.us     95
# 214           www.cimarronks.org               cimarronks.org     95
# 215              ci.waseca.mn.us          www.ci.waseca.mn.us     95
# 192   www.mifflinburgborough.org       mifflinburgborough.org     95
# 237   www.cityofwatervilleks.org       cityofwatervilleks.org     95
# 123                www.cmec.coop                 www.cme.coop     96
# 280                 www.sceg.com                  www.sce.com     96
# 40                   www.sce.com                 www.sceg.com     96
# 19                  www.cme.coop                www.cmec.coop     96

# %%
#index values of replacement that should occur
dup_ix = [332,238,248,310,90,296,155,219,174,141,190,202,215]

# %%
len(results)
# Out:
# 57

# %% [markdown]
# # TO DO
# 1. Pull scrapy log data into a DataFrame for more thorough cleaning/parsing
#     1. Collect lines that contain "DEBUG: Crawled" into a list of str
#     2. Push that list into a DataFrame and split the results on " DEBUG: Crawled (200) ", discarding `[0]` in favor of `[1]`
#     3. From `[1]` get URL
#         * URL = regex find on `"<GET ...url...>"`
#     3. Perform fuzzy matching on existing domains to make sure we correctly associate with all possible matched to get a semi-reasonable % matched
#     4. Associate final URL (no http or https) with `[Utility Domain (WWW Only)]` unduplicated entries, setting `['Crawling_Allowed'] = True` for those. Then figure out what fraction of the total number of nonduplicated domains have successful crawls
# 2. Come up with a more explicit way of determining if robots.txt is blocking us from rate pages
#     * Actually try crawling the tariff sheet URL we have on file, but only one per domain to speed things up, even if just a rough estimate
#     * Figure out from this what a blocking robots.txt looks like in the logs, keeping in mind that redirects may simply be going from `http` to `https` or something similar that isn't a true block
# 3. For those with `Crawling_Allowed = True`, use their `Num_Ratepayers` value their score and final metric of "% Allowed" will be `(URLs['Num_Ratepayers'] * URLs['Crawling_Allowed']).sum()/URLs['Num_Ratepayers'].sum()`
